# %% [markdown]
# # Prerequisites for Class "Special Topics in Galaxies and Cosmology"

# %% [markdown]
# You will need some basic knowledge of Cosmology in order to follow this class. If you have never taken a Cosmology class then I would recommend reading the following ahead of the class:
#
# http://www.astronomy.ohio-state.edu/~dhw/A5682/notes3.pdf
#
# http://www.astronomy.ohio-state.edu/~dhw/A873/notes3.pdf
#
# https://en.wikipedia.org/wiki/Friedmann_equations
#
# This lecture by Frank van den Bosch: http://www.astro.yale.edu/vdbosch/astro610_lecture3.pdf
#
# Chapters 1-6 of Barbara Ryden's "Introduction to Cosmology"
#
# __Please note that the chapters and sections that are refered to in this class are for the second edition of Ryden's book__. If you have an earlier edition, the chapter numbers may not line up.
#
# Distance measures in Cosmology by Daivd Hogg: https://arxiv.org/abs/astro-ph/9905116

# %% [markdown]
# I will assume that you have a basic working knowledge of the following equations and concepts:
#
# Scale Factor: $a= 1/(1+z)$
# * The scale factor in the FRW metric relates coordiantes $(r,\theta,\phi)$ to true physical distances.
# * Proper distance = scale factor x comoving distance. $r=a(t) \times \chi=\chi/(1+z)$ where $\chi$ is the comoving distance.
#
# A *comoving distance* between two objects in the Universe is the distance between them which remains constant with epoch if the two objects are moving with the Hubble flow (with the expansion of the Universe). Comoving distance factors out the expansion of the universe, giving a distance that does not change in time due to the expansion of space. The distance between two galaxy clusters is best considered in terms of a comoving distance.
#
# The distance between stars in a galaxy, or the sizes of galaxies, are best considered in terms of a *physical* or *proper* distance.
#
#
# By convention, the scale factor is set to 1 at the present time: $a(t_{today})=1$. As a result, the *comoving distance is equal to the proper distance at the present day*. This can also be seen by setting $z=0$ (today) in the equation    $r=a(t) \times \chi=\chi/(1+z)$
#
# When computing proper and comoving distances will be different depending on if you are considering two points at the same redshift, or at different redshifts. At fixed redshift (e.g. the distance between two galaxies at the same redshift), one can use the equation given above.
#
#
# Hubble parameter: $H(t)=\dot{a(t)}/a(t)$. The value of the Hubble parameter at the present day is called the Hubble parameter. It describes the present day expansion rate of the universe. $H_0 \sim 70$ km s$^{-1}$ Mpc$^{-1}$ (yes, these are odd units).
#
# Critical Density: $\rho_{crit,0}=3H_0^2/8\pi G$
#
# Density parameters: $\Omega_0=\rho_0/\rho_{crit,0}$, and $\Omega_0=\Omega_{m,0}+\Omega_{r_0}+\Omega_{\Lambda,0}$ (matter, radiation, and dark energy)
# - non-relativisitic matter energy density changes as $\rho_m \propto a^{-3}$
# - relativisitic matter (such as photons) energy density changes as $\rho_m \propto a^{-4}$ (the number density changes as $a^{-3}$ while the energy is redshifted according to $a^{-1}$)
# - vacuum energy, of the cosmological cosntant $\Lambda$ whose density is a constant
#
#
# The Friedmann-Robertson-Walker (FRW) Metric. The parameter K in the FRW metric is called the curvature parameter. It indicates the global curvature of space time. It can take on values +1,0,-1. Current constraints are consistent with a flat universe with K=0.
#
# The *Friedmann equations* (named after <a href="https://en.wikipedia.org/wiki/Alexander_Friedmann">Alexander Friedmann</a>, who first derived them in 1922):
#
# $$
# \frac{\ddot{a}}{a}=-\frac{4\pi G}{3}\left(\rho+3\frac{P}{c^2}\right)+\frac{\Lambda c^2}{3}.
# $$
# $$
# \left(\frac{\dot{a}}{a}\right)^2=\frac{8\pi G}{3}\rho+\frac{\Lambda c^2}{3}-\frac{Kc^2}{a^2}.
# $$
#
# The Friedmand equations relate the scale factor $a(t)$ to the energy density $\rho$ and the curvature $K$.
#
# The more commonly used, compact form of the Friedmann equation is: $H(t)=H_0 \times E(z)$ where the $E(z)$ function is (assuming K=0 or $\Omega_0=1$):
#
# $$E(z)=\sqrt{\Omega_{\Lambda,0}+\Omega_{M,0}(1+z)^3 + \Omega_{r,0}(1+z)^4}$$
#
#
# *Notice the different redshift dependence for different components (dark energy, dark matter, radiation)*

# %% [markdown]
# # Cloning the repository

# %% [markdown]
# The first thing for you to do is to clone the repository associated with this class.
# The repository is a private repository - you will get an invitation to join.
#
# in a terminal do:
#
# git clone https://github.com/alexieleauthaud/ASTR214_2017.git
#
# You yourself will never add things to this repo (you should not "push").
# However, I will add things to this repository as we go along.
# To update the repository do:
#
# git pull
#
# This repository has a directory called
#
# /classcode
#
# where useful code is stored and another called
#
# /data
#
# where data is stored
#
# If you want to take notes directly in the notebooks, you should make a local copy somewhere else on your machine.

# %% [markdown]
# # Making your own version of the class repository

# %% [markdown]
# Now make your own repository called : ASTR214_your name.
#
# Go to settings and make this a private repository.
#
# Go to setting and then collabortors and add me as a collaborator. My githandle is alexieleauthaud
#
# This is where you will upload coding homework exercices.

# %% [markdown]
# # Getting your python set up

# %% [markdown]
# ### Practical info on python and required packages.
#
# Throughout this class, we will be using python with jypter notebook.
#
# Prior to this class, you will need to get python, and jypter notebooks working on your laptop and to install the necessary packages for this class.
#
# **IMPORTANT**: we will be using python 3, please make sure you have python 3 installed. If you have already been using python 2 and don't want to switch to python 3, then please install python 3 into a virtual environment.
#
# You can find some information about getting set up here:
#
# <a href="https://github.com/alexieleauthaud/RedWoodTools/wiki/NoteBooks">Notebook set up</a>
#
# <a href="https://github.com/alexieleauthaud/RedWoodTools/wiki/Python">Python set up</a>
#
# The rationale for using Notebooks can be found <a href="http://pgbovine.net/ipython-notebook-first-impressions.htm">here</a> - it simplifies the work flow and closely connects plots with the code that produces them.
#
# For this class, in addition to the standard libraries (matplotlib, numpy, scipy, that should already be installed by Anaconda) you will need to install the following packages:

# %% [markdown]
# ### Required python packages
#
# <tt>pyfits</tt> - a package for reading FITS files.

# %% [markdown]
# <a href="https://bitbucket.org/bdiemer/colossus/overview"><tt>colossus</tt></a> - Benedikt Diemer's  python package containing useful routines for computing various cosmological quantities (distances, variances, power spectra, halo profiles, etc.) that we will be using throughout this course)

# %% [markdown]
# <tt><a href="http://scikit-learn.org/stable/">scikit-learn</a></tt> - python package containing various useful machine learning routines. The routines are also used by the AstroML package.

# %% [markdown]
# <tt><a href="https://pypi.python.org/pypi/astroML/">AstroML</a></tt> - this library was developed to support the book <a href="http://press.princeton.edu/titles/10159.html">''Statistics, Data Mining, and Machine Learning in Astronomy''</a> by Ivezic et al. The book itself is not needed for this course.

# %% [markdown]
# ### Preliminaries: set up plotting parameters

# %%
# First try and see if you directories are set up correctly
# Place yourself in the directory where this notebook is located
# And run this notebook up to this cell.
# You should get no error messages

import numpy as np
from classcode.read_sdss_fits import read_sdss_fits
from classcode.setupdir import notes_home_dir
from classcode.setupdir import code_home_dir
from classcode.setupdir import data_home_dir

# This should simply point to the current directory
print(notes_home_dir())

# And these to the code and data directories
print(code_home_dir())
print(data_home_dir())
# Out:
# /Users/alexie/Work/Teaching/SpecialTopicsGalaxiesCosmology/ASTR214_2019
# /Users/alexie/Work/Teaching/SpecialTopicsGalaxiesCosmology/ASTR214_2019/classcode
# /Users/alexie/Work/Teaching/SpecialTopicsGalaxiesCosmology/ASTR214_2019/data

# %%
# You can add this to the top of notebooks in order to make pretty inline figures
# Make sure to run these notebooks from the current directory so that you can acess the code under /classcode.
# Try running this cell to see if you have everything set up correctly so far
# you should get no error messages

# %matplotlib inline
import matplotlib.pyplot as plt

from classcode.plot_utils import plot_pretty
plot_pretty(dpi=300)

# %% [markdown]
# ### SDSS DR8 galaxy sample

# %% [markdown]
# For some exercises we will be using SDSS data.
# Download <a href="https://www.dropbox.com/s/bu625ewvdv48jkl/SDSSspecgalsDR8full.fits?dl=0">this SDSS file</a> (165 Mb).
# Put this file under the /data directory.
#
# This is a binary FITS file containing data from the SDSS survey and was produced by running an SQL query on the SDSS <a href="http://skyserver.sdss.org/CasJobs/">CasJobs server</a>.
#
# The SDSS FITS file used is large because it includes a number of properties and because it selects almost all low-z galaxies from the SDSS (called the main galaxy sample, to differentiate from the quasar and LRG samples).
#
# The SQL script used to produce the FITS file below can be found <a href="http://astro.uchicago.edu/~andrey/classes/a304s17/data/query_SDSSspecgalsDR8full.fit.txt">here.</a>
#
# A description of various entries for SDSS galaxies in DR8 can be found <a href="http://skyserver.sdss.org/dr8/en/help/browser/browser.asp">here</a>.
#
# If you have not queried SDSS data base yet, I encourage you to use this example, to create CasJobs account and construct your own queries for particular properties (but this is not a necessary step for this class).
#
# The code for reading SDSS fits file can be found in classcode/read_sdss_fits.

# %% [markdown]
# ### Let's practice! Read the fits table of the SDSS spectroscopic galaxy sample

# %% [markdown]
# Look at the code below and try to understand what it is doing.

# %%
from classcode.read_sdss_fits import read_sdss_fits
from classcode.setupdir import data_home_dir

# The print out below should show the directory where the sdss data file is stored
# It should be: /your_path/ASTR214_2017/data
data_home_dir()
print(data_home_dir())

# read fits file with the SDSS DR8 main spectroscopic sample
data = read_sdss_fits(data_home_dir()+'/SDSSspecgalsDR8full.fits')
# Out:
# /Users/alexie/Work/Teaching/SpecialTopicsGalaxiesCosmology/ASTR214_2019/data
# /anaconda3/lib/python3.7/site-packages/pyfits/__init__.py:22: PyFITSDeprecationWarning: PyFITS is deprecated, please use astropy.io.fits
#   PyFITSDeprecationWarning)  # noqa

# %%
# let's see the names of the quantities available in the SDSS table
import pyfits

hdulist = pyfits.open(data_home_dir()+'/SDSSspecgalsDR8full.fits')

print(hdulist[1].columns.names)
# Out:
# ['ra', 'dec', 'mjd', 'plate', 'fiberID', 'class', 'z', 'zErr', 'rChi2', 'velDisp', 'velDispErr', 'extinction_r', 'extinction_g', 'petroMag_r', 'psfMag_r', 'psfMagErr_r', 'modelMag_u', 'modelMagErr_u', 'modelMag_g', 'modelMagErr_g', 'modelMag_r', 'modelMagErr_r', 'modelMag_i', 'modelMagErr_i', 'modelMag_z', 'modelMagErr_z', 'cmodelMag_u', 'cmodelMagErr_u', 'cmodelMag_g', 'cmodelMagErr_g', 'cmodelMag_r', 'cmodelMagErr_r', 'cmodelMag_i', 'cmodelMagErr_i', 'petroR50_r', 'petroR90_r', 'petroR50Err_r', 'petroR90Err_r', 'fracdeV_r', 'expRad_r', 'expRadErr_r', 'deVRad_r', 'deVRadErr_r', 'deVMag_r', 'deVMagErr_r', 'expMag_r', 'expMagErr_r', 'lnLDeV_r', 'lnLExp_r', 'deVAB_r', 'deVABErr_r', 'expAB_r', 'expABErr_r', 'h_alpha_flux', 'h_alpha_flux_err', 'oiii_5007_flux', 'oiii_5007_flux_err', 'd4000', 'd4000_err', 'bptclass', 'lgm_tot_p50', 'sfr_tot_p50', 'objID', 'specObjID']

# %% [markdown]
# To find out what these different field mean, consult the <a href="https://skyserver.sdss.org/dr12/en/help/browser/browser.aspx">SDSS DR8 Galaxy table schema browser.</a>

# %% [markdown]
# ### Look at galaxies from the SDSS spectroscopic sample

# %% [markdown]
# Display a random selection of galaxies with a given range of parameters in an array (collage) of thumbnail images.

# %%
# This takes a minute or two to run ...

import numpy as np
from classcode.plot_utils import sdss_img_collage

# the number of rows and columns in the image collage
nrow = 5; ncol = 5

# pixel size of the thumbnails to extract from SDSS
npix = 130

# R band magnitude
mcmodel = data['cmodelMag_r']
print(mcmodel)

# select galaxies brighter than 17th magnitude in the r-band
rdata = data[mcmodel<17]
print("selected %d galaxies"%np.size(rdata))

# select a random subset of galaxies from the selected subset
iran = np.random.randint(0., np.size(rdata)-1, nrow*ncol)

# get data for the randomly selected galaxies
dshow = rdata[iran]
objs = dshow['objID']; ras = dshow['ra']; decs = dshow['dec']

# get images (if they are not yet on disk) and display the collage 
sdss_img_collage(objs, ras, decs, nrow, ncol, npix, scale=0.5)
# Out:
# [15.917929 17.659513 17.59069  ... 17.326408 17.722607 17.776653]
# selected 245592 galaxies

# %%
# Now check that you have colossus package

# colossus can be used to define a cosmology
from colossus.cosmology import cosmology

# set cosmology to the best values from 9-year WMAP data
cosmo = cosmology.setCosmology('WMAP9')

# Print the values of this cosmology
print(cosmo)

# What does flat=True mean?

# Pay particular attention to the value of the hubble constant!

print("\n Pay attention to the value of this parameter: h=",cosmo.h)
# Out:
# Cosmology "WMAP9"
#     flat = True, Om0 = 0.2865, Ode0 = 0.7134, Ob0 = 0.0463, H0 = 69.32, sigma8 = 0.8200, ns = 0.9608
#     de_model = lambda, relspecies = True, Tcmb0 = 2.7255, Neff = 3.0460, powerlaw = False
#
#  Pay attention to the value of this parameter: h= 0.6931999999999999

# %% [markdown]
# ### Understand the difference between H0 and h ("little h")
#
# Read <a href="http://adsabs.harvard.edu/abs/2013PASA...30...52C">Darren Croton's document on h.</a>
#
# **Make a mental note to always check in paper what value is assumed for H0 and little h and to explicitly state what your assumptions are in your papers for H0 and little h.**
#
# Note: in the first or second class, I will ask someone to come to the board to write down the value of H0 and the units of H0 and to explain little h.

# %% [markdown]
# ### Luminosity and Angular Diameter distances

# %%
# compute luminosity distance 
z=0.5
d_L = cosmo.luminosityDistance(z)/cosmo.h
print(d_L)

#and angular diameter distances
d_A = d_L/(1.+z)**2
print(d_A)
# Out:
# 2874.10055977899
# 1277.37802656844

# %% [markdown]
# Compare with the values from <a href="http://www.astro.ucla.edu/~wright/CosmoCalc.html">Ned Wright's Cosmology calculator.</a>
#
# What are the units of d_L and d_A?

# %% [markdown]
# ### You are ready for class!

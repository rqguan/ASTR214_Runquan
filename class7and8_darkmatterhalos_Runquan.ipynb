# %% [markdown]
# # Merger Trees, Halo Bias, Structure of Dark Matter Halos

# %% [markdown]
# What are we going to learn in this class?
# * how do halos grow?
# * what are the shapes and sizes of dark matter halos?
#
# We will broadly follow <a href="http://www.astro.yale.edu/vdbosch/astro610_lecture10.pdf">Lecture 10</a> and <a href="http://www.astro.yale.edu/vdbosch/astro611_lecture10.pdf">Lecture 11</a> by F. van den Bosch.
#
# Reading homework:
#
# * <a href="http://adsabs.harvard.edu/abs/2014ApJ...789....1D">Dependence of the Outer Density Profiles of Halos on Their Mass Accretion Rate</a>
#
# * <a href="https://arxiv.org/pdf/1703.09716.pdf">THE SPLASHBACK RADIUS OF HALOS FROM PARTICLE DYNAMICS. II. DEPENDENCE ON MASS, ACCRETION RATE, REDSHIFT, AND COSMOLOGY</a>

# %% [markdown]
# ## Merger Trees

# %% [markdown]
# Videos of the formation of a cluster from cosmosim.org:
#
# * <a href="https://www.cosmosim.org/resources/simus/MDR1_cl01_dm_evol_zoom.mp4"> The Dark Matter Component</a>
# * <a href="https://www.cosmosim.org/resources/simus/MDR1_cl01_evol_zoom_combine_gas_stars.mp4"> Gas and Stars</a>
#
# Notice:
# * large stuctures are built of gradually by devouring smaller ones.
# * gas and stars follow dark matter (this is why we care about the properties of the DM distribution for understanding galaxies - they are gravitationally tied to the DM component)

# %% [markdown]
# We can create a map of all of the small halos that merged to form the larger object - this "map" is called a **merger tree**.

# %% [markdown]
# Another reason we care about merger trees. They are critical in order to build *Semi-Analytic Models of galaxy formation (SAMs)*. SAMs are build on top of halo merger trees.
#
# **NOTE**: the merger trees can either be produced analytically (the details of how to do this are in Frank's lectures note, but we will skip those details here), or built from N-body simulations. For a brief description of this process, read  <a href="https://ned.ipac.caltech.edu/level5/March12/Silk/Silk3.html">this page on NED</a>.

# %% [markdown]
# <img width=400 align=left src="slidesfigs/merger_tree.png"></img>

# %% [markdown]
# <a href="http://adsabs.harvard.edu/abs/1993MNRAS.262..627L"> Figure taken from Lacey and Cole 1993, Merger rates in hierarchical models of galaxy formation.</a>

# %% [markdown]
#  **Bonus Homework (and term paper topic)**
#
#  Read a recent study on merger trees by  <a href=" https://arxiv.org/abs/1311.5225">Jiang et al. 2013</a> and merger trees from simulations using  <a href="https://arxiv.org/abs/1110.4370">Consistent Trees</a> by Peter Behroozi.

# %% [markdown]
# <img width=800 align=left src="slidesfigs/astro610_lecture10-15.png"></img>

# %% [markdown]
# <img width=800 align=left src="slidesfigs/astro610_lecture10-16.png"></img>

# %% [markdown]
# <img width=800 align=left src="slidesfigs/astro610_lecture10-17.png"></img>

# %% [markdown]
# <img width=800 align=left src="slidesfigs/astro610_lecture10-18.png"></img>

# %% [markdown]
# <img width=800 align=left src="slidesfigs/astro610_lecture10-19.png"></img>

# %% [markdown]
# <img width=800 align=left src="slidesfigs/astro610_lecture10-20.png"></img>

# %% [markdown]
# <img width=800 align=left src="slidesfigs/astro610_lecture10-21.png"></img>

# %% [markdown]
# **READING AND DISCUSSION**
#
# Read the Introduction and Section 3 in  <a href="https://arxiv.org/pdf/0803.2250.pdf"> Li et al. 2008</a>
#
# Is there a clear definition of the "formation time" of a dark matter halo?
#
# Is the same way, would there be a clear definition of the "formation time" of a galaxy?

# %% [markdown]
# ## Halo Bias

# %% [markdown]
# We now turn our attention to the spatial distribution of dark matter halos. Dark matter halos form from the dark matter field, so isn't the spatial distribution of dark matter halos the same as the underlying DM distirbution?
#
# The answer is *no* ...

# %% [markdown]
# <img width=800 align=left src="slidesfigs/astro610_lecture10-25.png"></img>

# %% [markdown]
# There are analytic ways of computing halo bias such as:
# * Extended press schecter theory
# * Peak background split

# %% [markdown]
# **TO REMEMBER**
#
# Using one of these methodologies (the EPS formalism) we can write down that:
#
# $$\delta_h(M,z) = b(M,z) \times \delta(z)$$
#
# Where b is the **halo bias** which according to EPS theory is:
#
# $$b(M,z)=1+(\frac{\nu^2-1}{\delta_c})$$

# %% [markdown]
# <img width=800 align=left src="slidesfigs/astro610_lecture10-29.png"></img>

# %% [markdown]
# **NOTICE**
#
# The mass-bias relation flattens below $M^*$. What does this mean in terms of inferring halo mass from the strength of galaxy clustering for low mass galaxies?

# %% [markdown]
# A widely used paper that provides a calibration of halo bias to numerical simulations by Tinker et al is:
#
#  <a href="http://adsabs.harvard.edu/abs/2010ApJ...724..878T">Tinker et al. 2010, The Large-scale Bias of Dark Matter Halos: Numerical Calibration and Model Tests</a>
#
# You should now have enough background to start to broadly understand the abstract from such papers. Let's take a look at the following:
#
# "We measure the clustering of dark matter halos in a large set of collisionless cosmological simulations of the flat $\Lambda$CDM cosmology. Halos are identified using the spherical overdensity algorithm, which finds the mass around isolated peaks in the density field such that the mean density is $\Delta$ times the background. We calibrate fitting functions for the large-scale bias that are adaptable to any value of $\Delta$ we examine. We find a ~6% scatter about our best-fit bias relation. Our fitting functions couple to the halo mass functions of Tinker et al. such that the bias of all dark matter is normalized to unity. We demonstrate that the bias of massive, rare halos is higher than that predicted in the modified ellipsoidal collapse model of Sheth et al. and approaches the predictions of the spherical collapse model for the rarest halos. Halo bias results based on friends-of-friends halos identified with linking length 0.2 are systematically lower than for halos with the canonical $\Delta$ = 200 overdensity by ~10%. In contrast to our previous results on the mass function, we find that the universal bias function evolves very weakly with redshift, if at all. We use our numerical results, both for the mass function and the bias relation, to test the peak-background split model for halo bias. We find that the peak-background split achieves a reasonable agreement with the numerical results, but ~20% residuals remain, both at high and low masses."
#
# *Questions?*

# %% [markdown]
# **READING HOMEWORK**
#
# Read  <a href="http://adsabs.harvard.edu/abs/2010ApJ...724..878T">Tinker et al. 2010, The Large-scale Bias of Dark Matter Halos: Numerical Calibration and Model Tests</a>

# %% [markdown]
# **EXERCICE**
#
# * Use https://bdiemer.bitbucket.io/halo_bias.html
# Compare the Tinker 2010 bias model with the EPS prediction, and the prediction from Ellipsoidal Collapse (equations are given above)

# %%
# Goal is to make a figure that is similar to Figure 1 in Tinker 2010
# plot b (bias) as a function of either Mhalo or nu - use a logarithmic x-axis
# Your code goes here 
import numpy as np
import matplotlib.pyplot as plt
from classcode.plot_utils import plot_pretty
plot_pretty(dpi=300)


from colossus.cosmology import cosmology
cosmo = cosmology.setCosmology('planck15')

from colossus.cosmology import cosmology
cosmo = cosmology.setCosmology('planck13')

from colossus.lss import peaks
from colossus.lss import bias


# halo masses in /h Msun
lmh = np.arange(7.,16.0,0.05)
mh = np.power(10.,lmh)

z = 0
nu = peaks.peakHeight(mh, z)

def EPS(v,d_cr):
    b = 1 + ((v**2-1)/d_cr)
    return b

def EC(v,d_cr):
    v0 = 0.84*v
    b = 1 + (d_cr**(-1))*(v0**2 + 0.5*(v0**0.8) - ((1.19*v0**1.2)/(v0**1.2 + 0.14)))
    return b

b_tinker = bias.modelTinker10(nu, z, "200c")

# Use the method "peak height" to convert to nu
# https://bdiemer.bitbucket.io/cosmology_cosmology.html#cosmology.cosmology.Cosmology.peakHeight
# modelTinker10(nu, z, mdef)  The halo bias model of Tinker et al 2010.

plt.plot(nu,EPS(nu,1.686),label='EPS')
plt.plot(nu,EC(nu,1.686),label='Ellipsoidal Collapse')
plt.plot(nu,b_tinker, label='Tinker10')
plt.xlabel(r'$\nu$'),plt.ylabel(r'$b$')
#plt.xscale('log')
plt.xlim(1,5),plt.ylim(0,10)
plt.legend()

# %% [markdown]
# ## Scale Dependent bias

# %% [markdown]
# **Important:**
#
# In practice, we distinguish *large scale linear bias* from *scale dependent bias*.
#
# We will return to this topic when we study *correlation functions* in the next few classes.

# %% [markdown]
# ## Assembly bias

# %% [markdown]
# <img width=800 align=left src="slidesfigs/astro610_lecture10-31.png"></img>

# %% [markdown]
# Assemlbly bias is currently a hot topic in structure formation. Many people are trying to measure this effect with some claimed detections, but nothing robust.
#
# Assembly bias was on of the major themes discussed at this  <a href="https://www.kitp.ucsb.edu/activities/galhalo-c17"> KITP workshop on the Galaxy Halo Connection</a>.
#
# Despite that fact that many of the experts were together in the same room, it was difficult to reach a consensus on the exact *definition* of assembly bias. Some of the main topics to be discussed were:
#
# * assembly bias was originally defined as differences in the clustering of halos at fixed halo mass (e.g., halo spin, halo age). Is this still the definition moving forward (my opinion is yes)?
# * does assembly bias manifest itself in galaxy properties?
# * how can it be robustly detected - difficulties with cluster finders.
#
# Why is assembly bias now a wide interest?
#
# * Because data sets are getting more precise and hence our measurements may be now senstitive to this effect.
# * We often use the clustering of galaxies to infer the underlying dark matter halo mass of the sample. If the properties of galaxies correlate with dark matter quanitites other than *mass*, then it may not be true that there is a one to one mapping between the clustering signal and halo mass.

# %% [markdown]
# Two papers to read on this topic:
#
# <a href="http://adsabs.harvard.edu/abs/2017arXiv170503888M">Mao et al. 2017, Beyond Assembly Bias: Exploring Secondary Halo Biases for Cluster-size Haloes</a>
#
# <a href="https://arxiv.org/pdf/0803.2250.pdf"> Li et etl 2008, On Halo Formation Times and Assembly Bias</a>

# %% [markdown]
# **DISCUSSION**
#
# Figure 4 in Li et al. 2008.

# %% [markdown]
# <img width=800 align=left src="slidesfigs/astro610_lecture11-06.png"></img>

# %% [markdown]
# What is the functional form that best describes the smooth component of a dark matter overdensity (halo) such as the one shown below?
#
# Also, some vocabulary:
# * parent halo
# * subhalo
# * substructure

# %% [markdown]
# <img width=800 align=left src="slidesfigs/astro610_lecture11-05.png"></img>

# %% [markdown]
# <img width=800 align=left src="slidesfigs/astro610_lecture11-08.png"></img>

# %% [markdown]
# <img width=800 align=left src="slidesfigs/astro610_lecture11-09.png"></img>

# %% [markdown]
# <img width=800 align=left src="slidesfigs/astro610_lecture11-10.png"></img>

# %% [markdown]
# <img width=800 align=left src="slidesfigs/astro610_lecture11-11.png"></img>

# %% [markdown]
# ** Note:** the maximum velocity, $V_{max}$, plays an important role in abundance matching (a tehcnique that we will study later in this class).

# %% [markdown]
# <img width=800 align=left src="slidesfigs/astro610_lecture11-12.png"></img>

# %% [markdown]
# <img width=800 align=left src="slidesfigs/astro610_lecture11-13.png"></img>

# %% [markdown]
# <img width=800 align=left src="slidesfigs/astro610_lecture11-21.png"></img>

# %% [markdown]
# Phew, that was a lot of slides!
#
# Let's do an application ...

# %% [markdown]
# Colossus has a *Dark Matter Halo* class. See what it does here:
#
# https://bdiemer.bitbucket.io/halo.html

# %% [markdown]
# In particular, look at the NFW class here:
#
# https://bdiemer.bitbucket.io/halo_profile_nfw.html#halo.profile_nfw.NFWProfile
#
# Let's plot an NFW profile:

# %%
# setup notebook for inline figures
# %matplotlib inline
import numpy as np

# import pyplot and set some parameters to make plots prettier
from classcode.plot_utils import plot_pretty
plot_pretty(dpi=300)

from colossus.cosmology import cosmology
from colossus.halo import profile_nfw

from colossus.cosmology import cosmology
cosmo = cosmology.setCosmology('planck15')

# %%
#https://bdiemer.bitbucket.io/halo_profile_nfw.html#halo.profile_nfw.NFWProfile
#profile = NFWProfile(M = 1E12, mdef = 'vir', z = 0.0, c = 10.0)

#R200m = profile.RDelta(0.0, '200m')

#R200m
#rho = profile.density(R200m)
#M = profile.enclosedMass(R200m)

Mvir = 1E15 # halo mass (clustered halo)
cvir = 5.0 # concentration parameter = r_halo/r_s
z = 0.0 # redshift
p_nfw = profile_nfw.NFWProfile(M = Mvir, c = cvir, z = z, mdef = 'vir')

r = 10**np.arange(0,4,0.02)
rho_m = cosmo.rho_m(z)
rho_nfw = p_nfw.density(r)

plt.figure()
plt.loglog()
plt.xlabel('r(kpc/h)')
plt.ylabel('density / mean')
plt.plot(r, rho_nfw / rho_m, '-', label = 'NFW');
plt.ylim(1E0, 1E7)

#Let's add the scale radius and virial radius for the NFW profile 
#for clarity. Spherical overdensity radii and masses can be obtained 
#with the RDelta/MDelta functions. The scale radius is part of the 
#internal parameters of the NFW model, and is thus an entry in the 
#par dictionary that each profile holds

Rvir_nfw = p_nfw.RDelta(z, 'vir')
print(p_nfw.par)
rs = p_nfw.par['rs']

plt.axvline(Rvir_nfw, ls = '--', label = 'Rvir (NFW)');
plt.axvline(rs, ls = ':', label = 'rs (NFW)');
plt.legend();
# Out:
# OrderedDict([('rhos', 1234985.1282420906), ('rs', 406.6211085021954)])

# %% [markdown]
# <img width=500 align=left src="slidesfigs/your_turn.JPG"></img>

# %% [markdown]
# 1) Vary the concentration parameter keeping Rvir fixed. How does the NFW profile change?
#
# 2) Consider dark matter halos with masses between Mhalo=10^11 and Mhalo=10^15
# At z=0, plot the virial radius as a function of halo mass

# %%
for i in np.logspace(0,2,5):
    Mvir = 1E15 # halo mass (clustered halo)
    cvir = i # concentration parameter = r_halo/r_s
    z = 0.0 # redshift
    p_nfw = profile_nfw.NFWProfile(M = Mvir, c = cvir, z = z, mdef = 'vir')

    r = 10**np.arange(0,4,0.02)
    rho_m = cosmo.rho_m(z)
    rho_nfw = p_nfw.density(r)
    plt.plot(r, rho_nfw / rho_m, '-', label = 'NFW'+str(round(i)));
    plt.loglog()
    plt.xlabel('r(kpc/h)')
    plt.ylabel('density / mean')
    
    plt.ylim(1E0, 1E7)

    Rvir_nfw = p_nfw.RDelta(z, 'vir')
    print(p_nfw.par)
    rs = p_nfw.par['rs']

    plt.axvline(Rvir_nfw, ls = '--', label = 'Rvir (NFW)'+str(round(i)));
    plt.axvline(rs, ls = ':', label = 'rs (NFW)'+str(round(i)));
    plt.legend();
# Out:
# OrderedDict([('rhos', 49025.49531055291), ('rs', 2033.1055425109769)])
# OrderedDict([('rhos', 449397.27950236166), ('rs', 642.9244237846975)])
# OrderedDict([('rhos', 6360228.667793403), ('rs', 203.3105542510977)])
# OrderedDict([('rhos', 119030348.03220716), ('rs', 64.29244237846976)])
# OrderedDict([('rhos', 2612160004.1983266), ('rs', 20.331055425109767)])

# %%
Mvir = np.logspace(10,16,100) # halo mass (clustered halo)
cvir = 5.0 # concentration parameter = r_halo/r_s
z = 0.0 # redshift
p_nfw = profile_nfw.NFWProfile(M = Mvir, c = cvir, z = z, mdef = 'vir')
Rvir_nfw = p_nfw.RDelta(z, 'vir')

plt.plot(Mvir,Rvir_nfw)
plt.loglog()
plt.xlabel('Halo Mass')
plt.ylabel('Virial Radius[kpc/h]')
# Out:
# Text(0, 0.5, 'Virial Radius[kpc/h]')

# %% [markdown]
# ## Halo Mass Definitions

# %% [markdown]
# We have seen that the mass of a dark matter halo is generally defined as follows
#
# $$M_{\Delta}=\frac{4}{3} \pi \Delta \rho_{\rm ref} R_{\Delta}^3$$
#
# where:
# * $\Delta$ is some overdensity
# * $\rho_{\rm ref}$ is either the *mean density* or the *critical density*
#
# However the problem is that:
# * there is no "unique" definition of halo mass
# * many different halo masses are used throughout the litterature.
#
# Let us review some of the main ones:
#
# * $M_{500c}$: $\Delta=500$, $\rho_{\rm ref}=$critical density
# * $M_{200c}$: $\Delta=200$, $\rho_{\rm ref}=$critical density
# * $M_{200m}$: $\Delta=200$, $\rho_{\rm ref}=$mean density
# * $M_{vir}$: $\Delta=\Delta_{vir}$, $\rho_{\rm ref}=$mean density

# %% [markdown]
# NOTE: if you are comparing halo masses, you need to make sure you understand which halo mass is being used, and also how to covert between different halo masses to make sure you are comparing apples to apples. Also, beware of $h$ factors in halo masses and make sure to convert halo masses to your assumed value of $h$.

# %% [markdown]
# ## What is the radius of a halo?

# %% [markdown]
# The question of what is the mass of a halo goes hand in hand with the question of: what is the radius of  halo?
#
# There has been a resurgence of interest in the topic and a set of papers advocating that the radius of a halo isn't just arbitrary, but that instead there is a physical meaning to the radius of a halo.

# %% [markdown]
# The following three slides were provided by Benedikt Diemer:

# %% [markdown]
# <img width=800 align=left src="slidesfigs/slides_alexie.012.png"></img>

# %% [markdown]
# <img width=800 align=left src="slidesfigs/slides_alexie.013.png"></img>

# %% [markdown]
# <img width=800 align=left src="slidesfigs/slides_alexie.014.png"></img>

# %% [markdown]
# <img width=800 align=left src="slidesfigs/slides_alexie.026.png"></img>

# %% [markdown]
# <img width=800 align=left src="slidesfigs/slides_alexie.027.png"></img>

# %% [markdown]
# <img width=800 align=left src="slidesfigs/slides_alexie.028.png"></img>

# %% [markdown]
# Two papers on the splashback radius:
#
# * <a href="http://adsabs.harvard.edu/abs/2014ApJ...789....1D">Dependence of the Outer Density Profiles of Halos on Their Mass Accretion Rate</a>
#
# * <a href="https://arxiv.org/pdf/1703.09716.pdf">THE SPLASHBACK RADIUS OF HALOS FROM PARTICLE DYNAMICS. II. DEPENDENCE ON MASS, ACCRETION RATE, REDSHIFT, AND COSMOLOGY</a>

# %% [markdown]
# HOWEVER: although the *splashback radius* may be more physical, it is difficult to idensity the splahback radius in simulations on a halo by halo masses - many many particles are required to robustly identify this radius. This makes this radius less practicul to use (currently) than other simple halo radii definition based on simple fixed $\Delta$ criteria.

# %% [markdown]
# However, there are new ideas under developement to determine the splashback radius on a halo by halo basis:
#
# Read about <a href="http://www.benediktdiemer.com/code/sparta/"> SPARTA</a> for example by <a href="http://adsabs.harvard.edu/abs/2017ApJS..231....5D"> Diemer et al 2017</a>.

# %% [markdown]
# ## Halo Shapes

# %% [markdown]
# <img width=800 align=left src="slidesfigs/astro610_lecture11-26.png"></img>

# %% [markdown]
# * Oblate = the pancake
# * Prolate = the cigar
# * triaxial = a and b and c are not equal
#
# <a href="https://en.wikipedia.org/wiki/Spheroid"> See the definition on Wikipedia.</a>

# %% [markdown]
# <img width=500 align=left src="slidesfigs/459px-Ellipsoid-rot-ax.svg.png"></img>

# %% [markdown]
# <img width=800 align=left src="slidesfigs/astro610_lecture11-27.png"></img>

# %% [markdown]
# ## Substructure

# %% [markdown]
# <img width=800 align=left src="slidesfigs/astro610_lecture11-29.png"></img>

# %% [markdown]
# Identifying substructure in N-body simulations is not a strightforward task, especially because of resolution effects. You will have the opportunity to study this question in more detail for the term paper research topics.
#
# This is a paper of relevence on this topic:
#
# <a href="http://adsabs.harvard.edu/abs/2017MNRAS.468..885V"> van den Bosch 2017, Dissecting the evolution of dark matter subhaloes in the Bolshoi simulation.</a>

# %% [markdown]
# ## Other Important Topics

# %% [markdown]
# There are three other important topics that I would like you to learn about in this section of the class. These are:
#
# * Pseudo evolution
# * A physical understanding of the mass-concentration relation
# * The splashback radius
#
# These topics will be covered by a guest lecture by Benedikt Diemer on Nov 7th.

# %% [markdown]
# **HOMEWORK**
#
# Go through the demos:
#
# * CodeDemos/colossus_demo_halo_concentration.ipynb
#
# * CodeDemos/colossus_demo_halo_profile.ipynb
#
# * CodeDemos/colossus_demo_halo_so.ipynb
#
# Install <a href="http://ds9.si.edu/site/Home.html"> DS9 </a> on your computer
#
# Download these two catalogs and put it under the data directory
#
# https://www.dropbox.com/s/b8ks6v72kvwcbhq/cosmos_acs_mag23.txt?dl=0
#
# https://www.dropbox.com/s/2phuj2r88nwuzth/COSMOS_borders_F814W_mask.fits?dl=0
#
# In the next class, we will be using astroML.correlation so please make sure to have the python astroML package working.
